# %% [markdown]
# #### TheCodeSpace

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain>=0.0.300 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.3.4)
# Requirement already satisfied: langchain-core>=0.0.15 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.3.12)
# Requirement already satisfied: langchain-community>=0.0.15 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.3.3)
# Requirement already satisfied: chromadb>=0.4.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.5.15)
# Requirement already satisfied: PyPDF2>=3.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: pypdf in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (5.1.0)
# Collecting gradio (from -r requirements.txt (line 7))
#   Obtaining dependency information for gradio from https://files.pythonhosted.org/packages/19/c6/bfab4a8c332e7c1f0c6c73213335a4980b516508a3900ce34a5d0400ae0b/gradio-5.6.0-py3-none-any.whl.metadata
#   Downloading gradio-5.6.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (2.0.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (3.8.5)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (0.1.136)
# Requirement already satisfied: numpy<2,>=1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain>=0.0.300->-r requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain-core>=0.0.15->-r requirements.txt (line 2)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain-core>=0.0.15->-r requirements.txt (line 2)) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain-core>=0.0.15->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain-community>=0.0.15->-r requirements.txt (line 3)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langchain-community>=0.0.15->-r requirements.txt (line 3)) (2.6.0)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.115.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.32.0)
# Requirement already satisfied: posthog>=2.4.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (3.7.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: pypika>=0.48.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (1.67.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (3.10.9)
# Requirement already satisfied: httpx>=0.27.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from chromadb>=0.4.8->-r requirements.txt (line 4)) (13.9.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio->-r requirements.txt (line 7)) (22.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio->-r requirements.txt (line 7)) (3.5.0)
# Collecting ffmpy (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for ffmpy from https://files.pythonhosted.org/packages/ff/1e/db99aa669eee301966bc6c997d60a0240f9cecae63f044b2e5a5310e4bf7/ffmpy-0.4.0-py3-none-any.whl.metadata
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.4.3 (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for gradio-client==1.4.3 from https://files.pythonhosted.org/packages/bc/eb/e4875e6803531059026d82fe96d0cbddae0d4d6a8826b926e02d5399b816/gradio_client-1.4.3-py3-none-any.whl.metadata
#   Downloading gradio_client-1.4.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub>=0.25.1 (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for huggingface-hub>=0.25.1 from https://files.pythonhosted.org/packages/60/bf/cea0b9720c32fa01b0c4ec4b16b9f4ae34ca106b202ebbae9f03ab98cd8f/huggingface_hub-0.26.2-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio->-r requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio->-r requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: pillow<12.0,>=8.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio->-r requirements.txt (line 7)) (10.0.1)
# Collecting pydub (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for pydub from https://files.pythonhosted.org/packages/a6/53/d78dc063216e62fc55f6b2eebb447f6a4b0a59f55c8406376f76bf959b08/pydub-0.25.1-py2.py3-none-any.whl.metadata
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart==0.0.12 (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for python-multipart==0.0.12 from https://files.pythonhosted.org/packages/f5/0b/c316262244abea7481f95f1e91d7575f3dfcf6455d56d1ffe9839c582eb1/python_multipart-0.0.12-py3-none-any.whl.metadata
#   Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Collecting ruff>=0.2.2 (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for ruff>=0.2.2 from https://files.pythonhosted.org/packages/41/17/9885e4a0eeae07abd2a4ebabc3246f556719f24efa477ba2739146c4635a/ruff-0.8.0-py3-none-macosx_11_0_arm64.whl.metadata
#   Downloading ruff-0.8.0-py3-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting safehttpx<1.0,>=0.1.1 (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for safehttpx<1.0,>=0.1.1 from https://files.pythonhosted.org/packages/df/f7/55cdeed5889f2076fdb125bc87bb7ab0f1715c84b0a4619c44833d890f60/safehttpx-0.1.1-py3-none-any.whl.metadata
#   Downloading safehttpx-0.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting semantic-version~=2.0 (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for semantic-version~=2.0 from https://files.pythonhosted.org/packages/6a/23/8146aad7d88f4fcb3a6218f41a60f6c2d4e3a72de72da1825dc7c8f7877c/semantic_version-2.10.0-py2.py3-none-any.whl.metadata
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio->-r requirements.txt (line 7)) (0.40.0)
# Collecting tomlkit==0.12.0 (from gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for tomlkit==0.12.0 from https://files.pythonhosted.org/packages/68/4f/12207897848a653d03ebbf6775a29d949408ded5f99b2d87198bc5c93508/tomlkit-0.12.0-py3-none-any.whl.metadata
#   Using cached tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer>=0.9.0 (from chromadb>=0.4.8->-r requirements.txt (line 4))
#   Obtaining dependency information for typer>=0.9.0 from https://files.pythonhosted.org/packages/22/69/e90a0b4d0c16e095901679216c8ecdc728110c7c54e7b5f43a623bc4c789/typer-0.13.1-py3-none-any.whl.metadata
#   Downloading typer-0.13.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from gradio-client==1.4.3->gradio->-r requirements.txt (line 7)) (2023.4.0)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.4.3->gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for websockets<13.0,>=10.0 from https://files.pythonhosted.org/packages/95/aa/75fa3b893142d6d98a48cb461169bd268141f2da8bfca97392d6462a02eb/websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.300->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.300->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.300->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.300->-r requirements.txt (line 1)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.300->-r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.300->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.300->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.0.15->-r requirements.txt (line 3)) (3.23.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.0.15->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: certifi in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.25.1->gradio->-r requirements.txt (line 7)) (3.9.0)
# Collecting fsspec (from gradio-client==1.4.3->gradio->-r requirements.txt (line 7))
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/c6/b2/454d6e7f0158951d8a78c2e1eb4f69ae81beb8dca5fee9809c6c99e9d0d0/fsspec-2024.10.0-py3-none-any.whl.metadata
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.0.15->-r requirements.txt (line 2)) (2.1)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (2.35.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.58.0)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.26.18)
# Requirement already satisfied: durationpy>=0.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.0.300->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: coloredlogs in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.8->-r requirements.txt (line 4)) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.8->-r requirements.txt (line 4)) (24.3.25)
# Requirement already satisfied: protobuf in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.8->-r requirements.txt (line 4)) (4.25.5)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.11.1)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (6.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.8->-r requirements.txt (line 4)) (68.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.8->-r requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 7)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 7)) (2023.3)
# Requirement already satisfied: monotonic>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.0.300->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain>=0.0.300->-r requirements.txt (line 1)) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community>=0.0.15->-r requirements.txt (line 3)) (0.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (2.15.1)
# Requirement already satisfied: click>=8.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb>=0.4.8->-r requirements.txt (line 4))
#   Obtaining dependency information for shellingham>=1.3.0 from https://files.pythonhosted.org/packages/e0/f9/0595336914c5619e5f28a1fb793285925a8cd4b432c9da0a987836c7f822/shellingham-1.5.4-py2.py3-none-any.whl.metadata
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: httptools>=0.5.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (4.9)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.0.15->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.8->-r requirements.txt (line 4)) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.4.8->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.8->-r requirements.txt (line 4)) (0.4.8)
# Downloading gradio-5.6.0-py3-none-any.whl (57.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 5.5 MB/s eta 0:00:0000:0100:01
# Downloading gradio_client-1.4.3-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 6.8 MB/s eta 0:00:00a 0:00:01
# Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Using cached tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Downloading ruff-0.8.0-py3-none-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 6.0 MB/s eta 0:00:0000:0100:01
# Downloading safehttpx-0.1.1-py3-none-any.whl (8.4 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading typer-0.13.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.9 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pydub, websockets, tomlkit, shellingham, semantic-version, ruff, python-multipart, fsspec, ffmpy, huggingface-hub, typer, safehttpx, gradio-client, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 13.1
#     Uninstalling websockets-13.1:
#       Successfully uninstalled websockets-13.1
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.13.1 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.13.1 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.10.0 which is incompatible.
# Successfully installed ffmpy-0.4.0 fsspec-2024.10.0 gradio-5.6.0 gradio-client-1.4.3 huggingface-hub-0.26.2 pydub-0.25.1 python-multipart-0.0.12 ruff-0.8.0 safehttpx-0.1.1 semantic-version-2.10.0 shellingham-1.5.4 tomlkit-0.12.0 typer-0.13.1 websockets-12.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1) GroqCloudAPI=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
# 2) Download and Install ollama
# 3) https://ollama.com/library
# 4) ollama pull nomic-embed-text -> Pull this model

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_community import embeddings
from langchain_community.chat_models import ChatOllama
from langchain_community.embeddings import OllamaEmbeddings

loader = PyPDFDirectoryLoader("data")
the_text = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
docs = text_splitter.split_documents(the_text)

vectorstore = Chroma.from_documents(
    documents=docs,
    collection_name="ollama_embeds",
    embedding=OllamaEmbeddings(model='nomic-embed-text'),
)

retriever = vectorstore.as_retriever()
# Out:
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 30 0 (offset 0)
# Ignoring wrong pointing object 34 0 (offset 0)
# Ignoring wrong pointing object 38 0 (offset 0)
# Ignoring wrong pointing object 42 0 (offset 0)
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 50 0 (offset 0)
# Ignoring wrong pointing object 59 0 (offset 0)
# Ignoring wrong pointing object 60 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 71 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 73 0 (offset 0)
# Ignoring wrong pointing object 74 0 (offset 0)
# Ignoring wrong pointing object 81 0 (offset 0)
# Ignoring wrong pointing object 85 0 (offset 0)
# Ignoring wrong pointing object 87 0 (offset 0)
# Ignoring wrong pointing object 91 0 (offset 0)
# Ignoring wrong pointing object 93 0 (offset 0)
# Ignoring wrong pointing object 101 0 (offset 0)
# Ignoring wrong pointing object 102 0 (offset 0)
# Ignoring wrong pointing object 103 0 (offset 0)
# Ignoring wrong pointing object 104 0 (offset 0)
# Ignoring wrong pointing object 105 0 (offset 0)
# Ignoring wrong pointing object 122 0 (offset 0)
# Ignoring wrong pointing object 123 0 (offset 0)
# Ignoring wrong pointing object 124 0 (offset 0)
# Ignoring wrong pointing object 127 0 (offset 0)
# Ignoring wrong pointing object 134 0 (offset 0)
# Ignoring wrong pointing object 135 0 (offset 0)
# Ignoring wrong pointing object 136 0 (offset 0)
# Ignoring wrong pointing object 149 0 (offset 0)
# Ignoring wrong pointing object 150 0 (offset 0)
# Ignoring wrong pointing object 151 0 (offset 0)
# Ignoring wrong pointing object 155 0 (offset 0)
# Ignoring wrong pointing object 161 0 (offset 0)
# Ignoring wrong pointing object 163 0 (offset 0)
# Ignoring wrong pointing object 165 0 (offset 0)
# Ignoring wrong pointing object 166 0 (offset 0)
# Ignoring wrong pointing object 174 0 (offset 0)
# Ignoring wrong pointing object 175 0 (offset 0)
# Ignoring wrong pointing object 177 0 (offset 0)
# Ignoring wrong pointing object 178 0 (offset 0)
# Ignoring wrong pointing object 183 0 (offset 0)
# Ignoring wrong pointing object 186 0 (offset 0)
# Ignoring wrong pointing object 190 0 (offset 0)
# Ignoring wrong pointing object 192 0 (offset 0)
# Ignoring wrong pointing object 193 0 (offset 0)
# Ignoring wrong pointing object 198 0 (offset 0)
# Ignoring wrong pointing object 199 0 (offset 0)
# Ignoring wrong pointing object 202 0 (offset 0)
# Ignoring wrong pointing object 210 0 (offset 0)
# Ignoring wrong pointing object 212 0 (offset 0)
# Ignoring wrong pointing object 213 0 (offset 0)
# Ignoring wrong pointing object 216 0 (offset 0)
# Ignoring wrong pointing object 220 0 (offset 0)
# Ignoring wrong pointing object 224 0 (offset 0)
# Ignoring wrong pointing object 238 0 (offset 0)
# Ignoring wrong pointing object 239 0 (offset 0)
# Ignoring wrong pointing object 240 0 (offset 0)
# Ignoring wrong pointing object 241 0 (offset 0)
# Ignoring wrong pointing object 242 0 (offset 0)
# Ignoring wrong pointing object 250 0 (offset 0)
# Ignoring wrong pointing object 251 0 (offset 0)
# Ignoring wrong pointing object 252 0 (offset 0)
# Ignoring wrong pointing object 257 0 (offset 0)
# Ignoring wrong pointing object 258 0 (offset 0)
# Ignoring wrong pointing object 259 0 (offset 0)
# Ignoring wrong pointing object 268 0 (offset 0)
# Ignoring wrong pointing object 269 0 (offset 0)
# Ignoring wrong pointing object 270 0 (offset 0)
# Ignoring wrong pointing object 279 0 (offset 0)
# Ignoring wrong pointing object 280 0 (offset 0)
# Ignoring wrong pointing object 281 0 (offset 0)
# Ignoring wrong pointing object 289 0 (offset 0)
# Ignoring wrong pointing object 290 0 (offset 0)
# Ignoring wrong pointing object 291 0 (offset 0)
# Ignoring wrong pointing object 303 0 (offset 0)
# Ignoring wrong pointing object 304 0 (offset 0)
# Ignoring wrong pointing object 305 0 (offset 0)
# Ignoring wrong pointing object 311 0 (offset 0)
# Ignoring wrong pointing object 312 0 (offset 0)
# Ignoring wrong pointing object 313 0 (offset 0)
# Ignoring wrong pointing object 317 0 (offset 0)
# Ignoring wrong pointing object 327 0 (offset 0)
# Ignoring wrong pointing object 328 0 (offset 0)
# Ignoring wrong pointing object 329 0 (offset 0)
# Ignoring wrong pointing object 347 0 (offset 0)
# Ignoring wrong pointing object 348 0 (offset 0)
# Ignoring wrong pointing object 349 0 (offset 0)
# Ignoring wrong pointing object 356 0 (offset 0)
# Ignoring wrong pointing object 357 0 (offset 0)
# Ignoring wrong pointing object 358 0 (offset 0)
# Ignoring wrong pointing object 368 0 (offset 0)
# Ignoring wrong pointing object 369 0 (offset 0)
# Ignoring wrong pointing object 370 0 (offset 0)
# Ignoring wrong pointing object 380 0 (offset 0)
# Ignoring wrong pointing object 381 0 (offset 0)
# Ignoring wrong pointing object 382 0 (offset 0)
# Ignoring wrong pointing object 389 0 (offset 0)
# Ignoring wrong pointing object 390 0 (offset 0)
# Ignoring wrong pointing object 391 0 (offset 0)
# Ignoring wrong pointing object 401 0 (offset 0)
# Ignoring wrong pointing object 402 0 (offset 0)
# Ignoring wrong pointing object 403 0 (offset 0)
# Ignoring wrong pointing object 410 0 (offset 0)
# Ignoring wrong pointing object 411 0 (offset 0)
# Ignoring wrong pointing object 412 0 (offset 0)
# Ignoring wrong pointing object 421 0 (offset 0)
# Ignoring wrong pointing object 422 0 (offset 0)
# Ignoring wrong pointing object 423 0 (offset 0)
# Ignoring wrong pointing object 431 0 (offset 0)
# Ignoring wrong pointing object 432 0 (offset 0)
# Ignoring wrong pointing object 433 0 (offset 0)
# Ignoring wrong pointing object 440 0 (offset 0)
# Ignoring wrong pointing object 441 0 (offset 0)
# Ignoring wrong pointing object 442 0 (offset 0)
# Ignoring wrong pointing object 453 0 (offset 0)
# Ignoring wrong pointing object 454 0 (offset 0)
# Ignoring wrong pointing object 455 0 (offset 0)
# Ignoring wrong pointing object 456 0 (offset 0)
# Ignoring wrong pointing object 457 0 (offset 0)
# Ignoring wrong pointing object 460 0 (offset 0)
# Ignoring wrong pointing object 472 0 (offset 0)
# Ignoring wrong pointing object 474 0 (offset 0)
# Ignoring wrong pointing object 475 0 (offset 0)
# Ignoring wrong pointing object 480 0 (offset 0)
# Ignoring wrong pointing object 481 0 (offset 0)
# Ignoring wrong pointing object 482 0 (offset 0)
# Ignoring wrong pointing object 483 0 (offset 0)
# Ignoring wrong pointing object 489 0 (offset 0)
# Ignoring wrong pointing object 491 0 (offset 0)
# Ignoring wrong pointing object 492 0 (offset 0)
# Ignoring wrong pointing object 497 0 (offset 0)
# Ignoring wrong pointing object 499 0 (offset 0)
# Ignoring wrong pointing object 505 0 (offset 0)
# Ignoring wrong pointing object 506 0 (offset 0)
# Ignoring wrong pointing object 508 0 (offset 0)
# Ignoring wrong pointing object 509 0 (offset 0)
# Ignoring wrong pointing object 514 0 (offset 0)
# Ignoring wrong pointing object 515 0 (offset 0)
# Ignoring wrong pointing object 521 0 (offset 0)
# Ignoring wrong pointing object 528 0 (offset 0)
# Ignoring wrong pointing object 530 0 (offset 0)
# Ignoring wrong pointing object 531 0 (offset 0)
# Ignoring wrong pointing object 536 0 (offset 0)
# Ignoring wrong pointing object 540 0 (offset 0)
# Ignoring wrong pointing object 542 0 (offset 0)
# Ignoring wrong pointing object 543 0 (offset 0)
# Ignoring wrong pointing object 548 0 (offset 0)
# Ignoring wrong pointing object 549 0 (offset 0)
# Ignoring wrong pointing object 555 0 (offset 0)
# Ignoring wrong pointing object 558 0 (offset 0)
# Ignoring wrong pointing object 560 0 (offset 0)
# Ignoring wrong pointing object 561 0 (offset 0)
# Ignoring wrong pointing object 566 0 (offset 0)
# Ignoring wrong pointing object 573 0 (offset 0)
# Ignoring wrong pointing object 574 0 (offset 0)
# Ignoring wrong pointing object 575 0 (offset 0)
# Ignoring wrong pointing object 576 0 (offset 0)
# Ignoring wrong pointing object 577 0 (offset 0)
# Ignoring wrong pointing object 580 0 (offset 0)
# Ignoring wrong pointing object 590 0 (offset 0)
# Ignoring wrong pointing object 591 0 (offset 0)
# Ignoring wrong pointing object 592 0 (offset 0)
# Ignoring wrong pointing object 599 0 (offset 0)
# Ignoring wrong pointing object 601 0 (offset 0)
# Ignoring wrong pointing object 603 0 (offset 0)
# Ignoring wrong pointing object 604 0 (offset 0)
# Ignoring wrong pointing object 612 0 (offset 0)
# Ignoring wrong pointing object 613 0 (offset 0)
# Ignoring wrong pointing object 614 0 (offset 0)
# Ignoring wrong pointing object 619 0 (offset 0)
# Ignoring wrong pointing object 624 0 (offset 0)
# Ignoring wrong pointing object 626 0 (offset 0)
# Ignoring wrong pointing object 627 0 (offset 0)
# Ignoring wrong pointing object 636 0 (offset 0)
# Ignoring wrong pointing object 637 0 (offset 0)
# Ignoring wrong pointing object 638 0 (offset 0)
# Ignoring wrong pointing object 643 0 (offset 0)
# Ignoring wrong pointing object 650 0 (offset 0)
# Ignoring wrong pointing object 652 0 (offset 0)
# Ignoring wrong pointing object 653 0 (offset 0)
# Ignoring wrong pointing object 661 0 (offset 0)
# Ignoring wrong pointing object 662 0 (offset 0)
# Ignoring wrong pointing object 663 0 (offset 0)
# Ignoring wrong pointing object 671 0 (offset 0)
# Ignoring wrong pointing object 673 0 (offset 0)
# Ignoring wrong pointing object 674 0 (offset 0)
# Ignoring wrong pointing object 679 0 (offset 0)
# Ignoring wrong pointing object 680 0 (offset 0)
# Ignoring wrong pointing object 689 0 (offset 0)
# Ignoring wrong pointing object 690 0 (offset 0)
# Ignoring wrong pointing object 691 0 (offset 0)
# Ignoring wrong pointing object 700 0 (offset 0)
# Ignoring wrong pointing object 701 0 (offset 0)
# Ignoring wrong pointing object 702 0 (offset 0)
# Ignoring wrong pointing object 714 0 (offset 0)
# Ignoring wrong pointing object 715 0 (offset 0)
# Ignoring wrong pointing object 716 0 (offset 0)
# Ignoring wrong pointing object 717 0 (offset 0)
# Ignoring wrong pointing object 718 0 (offset 0)
# Ignoring wrong pointing object 727 0 (offset 0)
# Ignoring wrong pointing object 728 0 (offset 0)
# Ignoring wrong pointing object 729 0 (offset 0)
# Ignoring wrong pointing object 733 0 (offset 0)
# Ignoring wrong pointing object 739 0 (offset 0)
# Ignoring wrong pointing object 741 0 (offset 0)
# Ignoring wrong pointing object 743 0 (offset 0)
# Ignoring wrong pointing object 744 0 (offset 0)
# Ignoring wrong pointing object 749 0 (offset 0)
# Ignoring wrong pointing object 756 0 (offset 0)
# Ignoring wrong pointing object 757 0 (offset 0)
# Ignoring wrong pointing object 758 0 (offset 0)
# Ignoring wrong pointing object 764 0 (offset 0)
# Ignoring wrong pointing object 765 0 (offset 0)
# Ignoring wrong pointing object 766 0 (offset 0)
# Ignoring wrong pointing object 774 0 (offset 0)
# Ignoring wrong pointing object 775 0 (offset 0)
# Ignoring wrong pointing object 776 0 (offset 0)
# Ignoring wrong pointing object 786 0 (offset 0)
# Ignoring wrong pointing object 787 0 (offset 0)
# Ignoring wrong pointing object 788 0 (offset 0)
# Ignoring wrong pointing object 798 0 (offset 0)
# Ignoring wrong pointing object 800 0 (offset 0)
# Ignoring wrong pointing object 801 0 (offset 0)
# Ignoring wrong pointing object 807 0 (offset 0)
# Ignoring wrong pointing object 808 0 (offset 0)
# Ignoring wrong pointing object 809 0 (offset 0)
# Ignoring wrong pointing object 812 0 (offset 0)
# Ignoring wrong pointing object 818 0 (offset 0)
# Ignoring wrong pointing object 819 0 (offset 0)
# Ignoring wrong pointing object 820 0 (offset 0)
# Ignoring wrong pointing object 829 0 (offset 0)
# Ignoring wrong pointing object 831 0 (offset 0)
# Ignoring wrong pointing object 832 0 (offset 0)
# Ignoring wrong pointing object 846 0 (offset 0)
# Ignoring wrong pointing object 848 0 (offset 0)
# Ignoring wrong pointing object 849 0 (offset 0)
# Ignoring wrong pointing object 854 0 (offset 0)
# Ignoring wrong pointing object 860 0 (offset 0)
# Ignoring wrong pointing object 862 0 (offset 0)
# Ignoring wrong pointing object 863 0 (offset 0)
# Ignoring wrong pointing object 868 0 (offset 0)
# Ignoring wrong pointing object 871 0 (offset 0)
# Ignoring wrong pointing object 872 0 (offset 0)
# Ignoring wrong pointing object 873 0 (offset 0)
# Ignoring wrong pointing object 880 0 (offset 0)
# Ignoring wrong pointing object 883 0 (offset 0)
# Ignoring wrong pointing object 885 0 (offset 0)
# Ignoring wrong pointing object 886 0 (offset 0)
# Ignoring wrong pointing object 898 0 (offset 0)
# Ignoring wrong pointing object 899 0 (offset 0)
# Ignoring wrong pointing object 900 0 (offset 0)
# Ignoring wrong pointing object 904 0 (offset 0)
# Ignoring wrong pointing object 906 0 (offset 0)
# Ignoring wrong pointing object 907 0 (offset 0)
# Ignoring wrong pointing object 912 0 (offset 0)
# Ignoring wrong pointing object 918 0 (offset 0)
# Ignoring wrong pointing object 920 0 (offset 0)
# Ignoring wrong pointing object 921 0 (offset 0)
# Ignoring wrong pointing object 922 0 (offset 0)
# Ignoring wrong pointing object 923 0 (offset 0)
# Ignoring wrong pointing object 934 0 (offset 0)
# Ignoring wrong pointing object 935 0 (offset 0)
# Ignoring wrong pointing object 936 0 (offset 0)
# Ignoring wrong pointing object 944 0 (offset 0)
# Ignoring wrong pointing object 946 0 (offset 0)
# Ignoring wrong pointing object 947 0 (offset 0)
# Ignoring wrong pointing object 952 0 (offset 0)
# Ignoring wrong pointing object 961 0 (offset 0)
# Ignoring wrong pointing object 963 0 (offset 0)
# Ignoring wrong pointing object 964 0 (offset 0)
# Ignoring wrong pointing object 972 0 (offset 0)
# Ignoring wrong pointing object 973 0 (offset 0)
# Ignoring wrong pointing object 974 0 (offset 0)
# Ignoring wrong pointing object 980 0 (offset 0)
# Ignoring wrong pointing object 982 0 (offset 0)
# Ignoring wrong pointing object 983 0 (offset 0)
# Ignoring wrong pointing object 995 0 (offset 0)
# Ignoring wrong pointing object 997 0 (offset 0)
# Ignoring wrong pointing object 998 0 (offset 0)
# Ignoring wrong pointing object 999 0 (offset 0)
# Ignoring wrong pointing object 1000 0 (offset 0)
# Ignoring wrong pointing object 1007 0 (offset 0)
# Ignoring wrong pointing object 1008 0 (offset 0)
# Ignoring wrong pointing object 1009 0 (offset 0)
# Ignoring wrong pointing object 1017 0 (offset 0)
# Ignoring wrong pointing object 1019 0 (offset 0)
# Ignoring wrong pointing object 1020 0 (offset 0)
# Ignoring wrong pointing object 1025 0 (offset 0)
# Ignoring wrong pointing object 1026 0 (offset 0)
# Ignoring wrong pointing object 1032 0 (offset 0)
# Ignoring wrong pointing object 1033 0 (offset 0)
# Ignoring wrong pointing object 1034 0 (offset 0)
# Ignoring wrong pointing object 1035 0 (offset 0)
# Ignoring wrong pointing object 1040 0 (offset 0)
# Ignoring wrong pointing object 1049 0 (offset 0)
# Ignoring wrong pointing object 1050 0 (offset 0)
# Ignoring wrong pointing object 1051 0 (offset 0)
# Ignoring wrong pointing object 1058 0 (offset 0)
# Ignoring wrong pointing object 1062 0 (offset 0)
# Ignoring wrong pointing object 1064 0 (offset 0)
# Ignoring wrong pointing object 1065 0 (offset 0)
# Ignoring wrong pointing object 1070 0 (offset 0)
# Ignoring wrong pointing object 1071 0 (offset 0)
# Ignoring wrong pointing object 1077 0 (offset 0)
# Ignoring wrong pointing object 1079 0 (offset 0)
# Ignoring wrong pointing object 1080 0 (offset 0)
# Ignoring wrong pointing object 1081 0 (offset 0)
# Ignoring wrong pointing object 1087 0 (offset 0)
# Ignoring wrong pointing object 1088 0 (offset 0)
# Ignoring wrong pointing object 1089 0 (offset 0)
# Ignoring wrong pointing object 1094 0 (offset 0)
# Ignoring wrong pointing object 1095 0 (offset 0)
# Ignoring wrong pointing object 1096 0 (offset 0)
# Ignoring wrong pointing object 1103 0 (offset 0)
# Ignoring wrong pointing object 1104 0 (offset 0)
# Ignoring wrong pointing object 1105 0 (offset 0)
# Ignoring wrong pointing object 1110 0 (offset 0)
# Ignoring wrong pointing object 1116 0 (offset 0)
# Ignoring wrong pointing object 1117 0 (offset 0)
# Ignoring wrong pointing object 1118 0 (offset 0)
# Ignoring wrong pointing object 1121 0 (offset 0)
# Ignoring wrong pointing object 1133 0 (offset 0)
# Ignoring wrong pointing object 1134 0 (offset 0)
# Ignoring wrong pointing object 1135 0 (offset 0)
# Ignoring wrong pointing object 1141 0 (offset 0)
# Ignoring wrong pointing object 1142 0 (offset 0)
# Ignoring wrong pointing object 1143 0 (offset 0)
# Ignoring wrong pointing object 1153 0 (offset 0)
# Ignoring wrong pointing object 1154 0 (offset 0)
# Ignoring wrong pointing object 1155 0 (offset 0)
# Ignoring wrong pointing object 1165 0 (offset 0)
# Ignoring wrong pointing object 1166 0 (offset 0)
# Ignoring wrong pointing object 1167 0 (offset 0)
# Ignoring wrong pointing object 1170 0 (offset 0)
# Ignoring wrong pointing object 1184 0 (offset 0)
# Ignoring wrong pointing object 1185 0 (offset 0)
# Ignoring wrong pointing object 1186 0 (offset 0)
# Ignoring wrong pointing object 1187 0 (offset 0)
# Ignoring wrong pointing object 1188 0 (offset 0)
# Ignoring wrong pointing object 1191 0 (offset 0)
# Ignoring wrong pointing object 1198 0 (offset 0)
# Ignoring wrong pointing object 1199 0 (offset 0)
# Ignoring wrong pointing object 1200 0 (offset 0)
# Ignoring wrong pointing object 1203 0 (offset 0)
# Ignoring wrong pointing object 1206 0 (offset 0)
# Ignoring wrong pointing object 1209 0 (offset 0)
# Ignoring wrong pointing object 1215 0 (offset 0)
# Ignoring wrong pointing object 1226 0 (offset 0)
# Ignoring wrong pointing object 1227 0 (offset 0)
# Ignoring wrong pointing object 1228 0 (offset 0)
# Ignoring wrong pointing object 1237 0 (offset 0)
# Ignoring wrong pointing object 1238 0 (offset 0)
# Ignoring wrong pointing object 1239 0 (offset 0)
# Ignoring wrong pointing object 1247 0 (offset 0)
# Ignoring wrong pointing object 1248 0 (offset 0)
# Ignoring wrong pointing object 1249 0 (offset 0)
# Ignoring wrong pointing object 1260 0 (offset 0)
# Ignoring wrong pointing object 1261 0 (offset 0)
# Ignoring wrong pointing object 1262 0 (offset 0)
# Ignoring wrong pointing object 1271 0 (offset 0)
# Ignoring wrong pointing object 1272 0 (offset 0)
# Ignoring wrong pointing object 1273 0 (offset 0)
# Ignoring wrong pointing object 1274 0 (offset 0)
# Ignoring wrong pointing object 1275 0 (offset 0)
# Ignoring wrong pointing object 1278 0 (offset 0)
# Ignoring wrong pointing object 1291 0 (offset 0)
# Ignoring wrong pointing object 1292 0 (offset 0)
# Ignoring wrong pointing object 1293 0 (offset 0)
# Ignoring wrong pointing object 1294 0 (offset 0)
# Ignoring wrong pointing object 1295 0 (offset 0)
# Ignoring wrong pointing object 1303 0 (offset 0)
# Ignoring wrong pointing object 1304 0 (offset 0)
# Ignoring wrong pointing object 1305 0 (offset 0)
# Ignoring wrong pointing object 1308 0 (offset 0)
# Ignoring wrong pointing object 1314 0 (offset 0)
# Ignoring wrong pointing object 1316 0 (offset 0)
# Ignoring wrong pointing object 1321 0 (offset 0)
# Ignoring wrong pointing object 1322 0 (offset 0)
# Ignoring wrong pointing object 1324 0 (offset 0)
# Ignoring wrong pointing object 1325 0 (offset 0)
# Ignoring wrong pointing object 1330 0 (offset 0)
# Ignoring wrong pointing object 1332 0 (offset 0)
# Ignoring wrong pointing object 1337 0 (offset 0)
# Ignoring wrong pointing object 1339 0 (offset 0)
# Ignoring wrong pointing object 1340 0 (offset 0)
# Ignoring wrong pointing object 1345 0 (offset 0)
# Ignoring wrong pointing object 1349 0 (offset 0)
# Ignoring wrong pointing object 1351 0 (offset 0)
# Ignoring wrong pointing object 1352 0 (offset 0)
# Ignoring wrong pointing object 1356 0 (offset 0)
# Ignoring wrong pointing object 1362 0 (offset 0)
# Ignoring wrong pointing object 1364 0 (offset 0)
# Ignoring wrong pointing object 1365 0 (offset 0)
# Ignoring wrong pointing object 1368 0 (offset 0)
# Ignoring wrong pointing object 1371 0 (offset 0)
# Ignoring wrong pointing object 1384 0 (offset 0)
# Ignoring wrong pointing object 1386 0 (offset 0)
# Ignoring wrong pointing object 1387 0 (offset 0)
# Ignoring wrong pointing object 1393 0 (offset 0)
# Ignoring wrong pointing object 1394 0 (offset 0)
# Ignoring wrong pointing object 1395 0 (offset 0)
# Ignoring wrong pointing object 1402 0 (offset 0)
# Ignoring wrong pointing object 1407 0 (offset 0)
# Ignoring wrong pointing object 1409 0 (offset 0)
# Ignoring wrong pointing object 1410 0 (offset 0)
# Ignoring wrong pointing object 1415 0 (offset 0)
# Ignoring wrong pointing object 1416 0 (offset 0)
# Ignoring wrong pointing object 1421 0 (offset 0)
# Ignoring wrong pointing object 1427 0 (offset 0)
# Ignoring wrong pointing object 1428 0 (offset 0)
# Ignoring wrong pointing object 1430 0 (offset 0)
# Ignoring wrong pointing object 1431 0 (offset 0)
# Ignoring wrong pointing object 1436 0 (offset 0)
# Ignoring wrong pointing object 1438 0 (offset 0)
# Ignoring wrong pointing object 1444 0 (offset 0)
# Ignoring wrong pointing object 1449 0 (offset 0)
# Ignoring wrong pointing object 1451 0 (offset 0)
# Ignoring wrong pointing object 1452 0 (offset 0)
# Ignoring wrong pointing object 1456 0 (offset 0)
# Ignoring wrong pointing object 1465 0 (offset 0)
# Ignoring wrong pointing object 1466 0 (offset 0)
# Ignoring wrong pointing object 1467 0 (offset 0)
# Ignoring wrong pointing object 1482 0 (offset 0)
# Ignoring wrong pointing object 1483 0 (offset 0)
# Ignoring wrong pointing object 1484 0 (offset 0)
# Ignoring wrong pointing object 1490 0 (offset 0)
# Ignoring wrong pointing object 1491 0 (offset 0)
# Ignoring wrong pointing object 1493 0 (offset 0)
# Ignoring wrong pointing object 1494 0 (offset 0)
# Ignoring wrong pointing object 1497 0 (offset 0)
# Ignoring wrong pointing object 1508 0 (offset 0)
# Ignoring wrong pointing object 1509 0 (offset 0)
# Ignoring wrong pointing object 1510 0 (offset 0)
# Ignoring wrong pointing object 1511 0 (offset 0)
# Ignoring wrong pointing object 1512 0 (offset 0)
# Ignoring wrong pointing object 1521 0 (offset 0)
# Ignoring wrong pointing object 1522 0 (offset 0)
# Ignoring wrong pointing object 1523 0 (offset 0)
# Ignoring wrong pointing object 1534 0 (offset 0)
# Ignoring wrong pointing object 1536 0 (offset 0)
# Ignoring wrong pointing object 1537 0 (offset 0)
# Ignoring wrong pointing object 1542 0 (offset 0)
# Ignoring wrong pointing object 1547 0 (offset 0)
# Ignoring wrong pointing object 1549 0 (offset 0)
# Ignoring wrong pointing object 1550 0 (offset 0)
# Ignoring wrong pointing object 1567 0 (offset 0)
# Ignoring wrong pointing object 1569 0 (offset 0)
# Ignoring wrong pointing object 1570 0 (offset 0)
# Ignoring wrong pointing object 1578 0 (offset 0)
# Ignoring wrong pointing object 1579 0 (offset 0)
# Ignoring wrong pointing object 1580 0 (offset 0)
# Ignoring wrong pointing object 1589 0 (offset 0)
# Ignoring wrong pointing object 1590 0 (offset 0)
# Ignoring wrong pointing object 1591 0 (offset 0)
# Ignoring wrong pointing object 1595 0 (offset 0)
# Ignoring wrong pointing object 1601 0 (offset 0)
# Ignoring wrong pointing object 1603 0 (offset 0)
# Ignoring wrong pointing object 1604 0 (offset 0)
# Ignoring wrong pointing object 1609 0 (offset 0)
# Ignoring wrong pointing object 1611 0 (offset 0)
# Ignoring wrong pointing object 1614 0 (offset 0)
# Ignoring wrong pointing object 1621 0 (offset 0)
# Ignoring wrong pointing object 1626 0 (offset 0)
# Ignoring wrong pointing object 1628 0 (offset 0)
# Ignoring wrong pointing object 1629 0 (offset 0)
# Ignoring wrong pointing object 1634 0 (offset 0)
# Ignoring wrong pointing object 1635 0 (offset 0)
# Ignoring wrong pointing object 1640 0 (offset 0)
# Ignoring wrong pointing object 1641 0 (offset 0)
# Ignoring wrong pointing object 1643 0 (offset 0)
# Ignoring wrong pointing object 1644 0 (offset 0)
# Ignoring wrong pointing object 1649 0 (offset 0)
# Ignoring wrong pointing object 1650 0 (offset 0)
# Ignoring wrong pointing object 1656 0 (offset 0)
# Ignoring wrong pointing object 1657 0 (offset 0)
# Ignoring wrong pointing object 1663 0 (offset 0)
# Ignoring wrong pointing object 1664 0 (offset 0)
# Ignoring wrong pointing object 1666 0 (offset 0)
# Ignoring wrong pointing object 1667 0 (offset 0)
# Ignoring wrong pointing object 1672 0 (offset 0)
# Ignoring wrong pointing object 1677 0 (offset 0)
# Ignoring wrong pointing object 1679 0 (offset 0)
# Ignoring wrong pointing object 1680 0 (offset 0)
# Ignoring wrong pointing object 1685 0 (offset 0)
# Ignoring wrong pointing object 1689 0 (offset 0)
# Ignoring wrong pointing object 1690 0 (offset 0)
# Ignoring wrong pointing object 1691 0 (offset 0)
# Ignoring wrong pointing object 1694 0 (offset 0)
# Ignoring wrong pointing object 1703 0 (offset 0)
# Ignoring wrong pointing object 1704 0 (offset 0)
# Ignoring wrong pointing object 1705 0 (offset 0)
# Ignoring wrong pointing object 1709 0 (offset 0)
# Ignoring wrong pointing object 1711 0 (offset 0)
# Ignoring wrong pointing object 1715 0 (offset 0)
# Ignoring wrong pointing object 1716 0 (offset 0)
# Ignoring wrong pointing object 1717 0 (offset 0)
# Ignoring wrong pointing object 1723 0 (offset 0)
# Ignoring wrong pointing object 1724 0 (offset 0)
# Ignoring wrong pointing object 1725 0 (offset 0)
# Ignoring wrong pointing object 1731 0 (offset 0)
# Ignoring wrong pointing object 1732 0 (offset 0)
# Ignoring wrong pointing object 1733 0 (offset 0)
# Ignoring wrong pointing object 1736 0 (offset 0)
# Ignoring wrong pointing object 1740 0 (offset 0)
# Ignoring wrong pointing object 1750 0 (offset 0)
# Ignoring wrong pointing object 1751 0 (offset 0)
# Ignoring wrong pointing object 1752 0 (offset 0)
# Ignoring wrong pointing object 1753 0 (offset 0)
# Ignoring wrong pointing object 1754 0 (offset 0)
# Ignoring wrong pointing object 1763 0 (offset 0)
# Ignoring wrong pointing object 1765 0 (offset 0)
# Ignoring wrong pointing object 1766 0 (offset 0)
# Ignoring wrong pointing object 1772 0 (offset 0)
# Ignoring wrong pointing object 1774 0 (offset 0)
# Ignoring wrong pointing object 1775 0 (offset 0)
# Ignoring wrong pointing object 1780 0 (offset 0)
# Ignoring wrong pointing object 1782 0 (offset 0)
# Ignoring wrong pointing object 1789 0 (offset 0)
# Ignoring wrong pointing object 1790 0 (offset 0)
# Ignoring wrong pointing object 1791 0 (offset 0)
# Ignoring wrong pointing object 1801 0 (offset 0)
# Ignoring wrong pointing object 1803 0 (offset 0)
# Ignoring wrong pointing object 1804 0 (offset 0)
# Ignoring wrong pointing object 1807 0 (offset 0)
# Ignoring wrong pointing object 1816 0 (offset 0)
# Ignoring wrong pointing object 1818 0 (offset 0)
# Ignoring wrong pointing object 1819 0 (offset 0)
# Ignoring wrong pointing object 1825 0 (offset 0)
# Ignoring wrong pointing object 1827 0 (offset 0)
# Ignoring wrong pointing object 1828 0 (offset 0)
# Ignoring wrong pointing object 1834 0 (offset 0)
# Ignoring wrong pointing object 1835 0 (offset 0)
# Ignoring wrong pointing object 1836 0 (offset 0)
# Ignoring wrong pointing object 1842 0 (offset 0)
# Ignoring wrong pointing object 1843 0 (offset 0)
# Ignoring wrong pointing object 1844 0 (offset 0)
# Ignoring wrong pointing object 1852 0 (offset 0)
# Ignoring wrong pointing object 1854 0 (offset 0)
# Ignoring wrong pointing object 1855 0 (offset 0)
# Ignoring wrong pointing object 1864 0 (offset 0)
# Ignoring wrong pointing object 1865 0 (offset 0)
# Ignoring wrong pointing object 1866 0 (offset 0)
# Ignoring wrong pointing object 1869 0 (offset 0)
# Ignoring wrong pointing object 1880 0 (offset 0)
# Ignoring wrong pointing object 1881 0 (offset 0)
# Ignoring wrong pointing object 1882 0 (offset 0)
# Ignoring wrong pointing object 1885 0 (offset 0)
# Ignoring wrong pointing object 1894 0 (offset 0)
# Ignoring wrong pointing object 1895 0 (offset 0)
# Ignoring wrong pointing object 1896 0 (offset 0)
# Ignoring wrong pointing object 1904 0 (offset 0)
# Ignoring wrong pointing object 1906 0 (offset 0)
# Ignoring wrong pointing object 1907 0 (offset 0)
# Ignoring wrong pointing object 1912 0 (offset 0)
# Ignoring wrong pointing object 1913 0 (offset 0)
# Ignoring wrong pointing object 1915 0 (offset 0)
# Ignoring wrong pointing object 1916 0 (offset 0)
# Ignoring wrong pointing object 1921 0 (offset 0)
# Ignoring wrong pointing object 1922 0 (offset 0)
# Ignoring wrong pointing object 1929 0 (offset 0)
# Ignoring wrong pointing object 1930 0 (offset 0)
# Ignoring wrong pointing object 1932 0 (offset 0)
# Ignoring wrong pointing object 1933 0 (offset 0)
# Ignoring wrong pointing object 1938 0 (offset 0)
# Ignoring wrong pointing object 1943 0 (offset 0)
# Ignoring wrong pointing object 1944 0 (offset 0)
# Ignoring wrong pointing object 1945 0 (offset 0)
# Ignoring wrong pointing object 1950 0 (offset 0)
# Ignoring wrong pointing object 1956 0 (offset 0)
# Ignoring wrong pointing object 1959 0 (offset 0)
# Ignoring wrong pointing object 1961 0 (offset 0)
# Ignoring wrong pointing object 1962 0 (offset 0)
# Ignoring wrong pointing object 1967 0 (offset 0)
# Ignoring wrong pointing object 1968 0 (offset 0)
# Ignoring wrong pointing object 1974 0 (offset 0)
# Ignoring wrong pointing object 1976 0 (offset 0)
# Ignoring wrong pointing object 1978 0 (offset 0)
# Ignoring wrong pointing object 1979 0 (offset 0)
# Ignoring wrong pointing object 1984 0 (offset 0)
# Ignoring wrong pointing object 1985 0 (offset 0)
# Ignoring wrong pointing object 1990 0 (offset 0)
# Ignoring wrong pointing object 1997 0 (offset 0)
# Ignoring wrong pointing object 1998 0 (offset 0)
# Ignoring wrong pointing object 1999 0 (offset 0)
# Ignoring wrong pointing object 2000 0 (offset 0)
# Ignoring wrong pointing object 2001 0 (offset 0)
# Ignoring wrong pointing object 2010 0 (offset 0)
# Ignoring wrong pointing object 2011 0 (offset 0)
# Ignoring wrong pointing object 2012 0 (offset 0)
# Ignoring wrong pointing object 2017 0 (offset 0)
# Ignoring wrong pointing object 2018 0 (offset 0)
# Ignoring wrong pointing object 2027 0 (offset 0)
# Ignoring wrong pointing object 2028 0 (offset 0)
# Ignoring wrong pointing object 2029 0 (offset 0)
# Ignoring wrong pointing object 2034 0 (offset 0)
# Ignoring wrong pointing object 2035 0 (offset 0)
# Ignoring wrong pointing object 2042 0 (offset 0)
# Ignoring wrong pointing object 2043 0 (offset 0)
# Ignoring wrong pointing object 2044 0 (offset 0)
# Ignoring wrong pointing object 2049 0 (offset 0)
# Ignoring wrong pointing object 2050 0 (offset 0)
# Ignoring wrong pointing object 2051 0 (offset 0)
# Ignoring wrong pointing object 2055 0 (offset 0)
# Ignoring wrong pointing object 2060 0 (offset 0)
# Ignoring wrong pointing object 2063 0 (offset 0)
# Ignoring wrong pointing object 2065 0 (offset 0)
# Ignoring wrong pointing object 2066 0 (offset 0)
# Ignoring wrong pointing object 2069 0 (offset 0)
# Ignoring wrong pointing object 2072 0 (offset 0)
# Ignoring wrong pointing object 2081 0 (offset 0)
# Ignoring wrong pointing object 2083 0 (offset 0)
# Ignoring wrong pointing object 2084 0 (offset 0)
# Ignoring wrong pointing object 2092 0 (offset 0)
# Ignoring wrong pointing object 2093 0 (offset 0)
# Ignoring wrong pointing object 2094 0 (offset 0)
# Ignoring wrong pointing object 2104 0 (offset 0)
# Ignoring wrong pointing object 2105 0 (offset 0)
# Ignoring wrong pointing object 2106 0 (offset 0)
# Ignoring wrong pointing object 2111 0 (offset 0)
# Ignoring wrong pointing object 2112 0 (offset 0)
# Ignoring wrong pointing object 2120 0 (offset 0)
# Ignoring wrong pointing object 2122 0 (offset 0)
# Ignoring wrong pointing object 2123 0 (offset 0)
# Ignoring wrong pointing object 2128 0 (offset 0)
# Ignoring wrong pointing object 2131 0 (offset 0)
# Ignoring wrong pointing object 2133 0 (offset 0)
# Ignoring wrong pointing object 2134 0 (offset 0)
# Ignoring wrong pointing object 2137 0 (offset 0)
# Ignoring wrong pointing object 2143 0 (offset 0)
# Ignoring wrong pointing object 2147 0 (offset 0)
# Ignoring wrong pointing object 2148 0 (offset 0)
# Ignoring wrong pointing object 2149 0 (offset 0)
# Ignoring wrong pointing object 2155 0 (offset 0)
# Ignoring wrong pointing object 2157 0 (offset 0)
# Ignoring wrong pointing object 2158 0 (offset 0)
# Ignoring wrong pointing object 2161 0 (offset 0)
# Ignoring wrong pointing object 2164 0 (offset 0)
# Ignoring wrong pointing object 2169 0 (offset 0)
# Ignoring wrong pointing object 2170 0 (offset 0)
# Ignoring wrong pointing object 2176 0 (offset 0)
# Ignoring wrong pointing object 2177 0 (offset 0)
# Ignoring wrong pointing object 2178 0 (offset 0)
# Ignoring wrong pointing object 2188 0 (offset 0)
# Ignoring wrong pointing object 2189 0 (offset 0)
# Ignoring wrong pointing object 2190 0 (offset 0)
# Ignoring wrong pointing object 2199 0 (offset 0)
# Ignoring wrong pointing object 2200 0 (offset 0)
# Ignoring wrong pointing object 2201 0 (offset 0)
# Ignoring wrong pointing object 2207 0 (offset 0)
# Ignoring wrong pointing object 2209 0 (offset 0)
# Ignoring wrong pointing object 2210 0 (offset 0)
# Ignoring wrong pointing object 2216 0 (offset 0)
# Ignoring wrong pointing object 2218 0 (offset 0)
# Ignoring wrong pointing object 2219 0 (offset 0)
# Ignoring wrong pointing object 2224 0 (offset 0)
# Ignoring wrong pointing object 2225 0 (offset 0)
# Ignoring wrong pointing object 2231 0 (offset 0)
# Ignoring wrong pointing object 2234 0 (offset 0)
# Ignoring wrong pointing object 2236 0 (offset 0)
# Ignoring wrong pointing object 2237 0 (offset 0)
# Ignoring wrong pointing object 2242 0 (offset 0)
# Ignoring wrong pointing object 2247 0 (offset 0)
# Ignoring wrong pointing object 2248 0 (offset 0)
# Ignoring wrong pointing object 2249 0 (offset 0)
# Ignoring wrong pointing object 2254 0 (offset 0)
# Ignoring wrong pointing object 2257 0 (offset 0)
# Ignoring wrong pointing object 2259 0 (offset 0)
# Ignoring wrong pointing object 2260 0 (offset 0)
# Ignoring wrong pointing object 2264 0 (offset 0)
# Ignoring wrong pointing object 2270 0 (offset 0)
# Ignoring wrong pointing object 2276 0 (offset 0)
# Ignoring wrong pointing object 2277 0 (offset 0)
# Ignoring wrong pointing object 2278 0 (offset 0)
# Ignoring wrong pointing object 2283 0 (offset 0)
# Ignoring wrong pointing object 2284 0 (offset 0)
# Ignoring wrong pointing object 2285 0 (offset 0)
# Ignoring wrong pointing object 2288 0 (offset 0)
# Ignoring wrong pointing object 2291 0 (offset 0)
# Ignoring wrong pointing object 2297 0 (offset 0)
# Ignoring wrong pointing object 2301 0 (offset 0)
# Ignoring wrong pointing object 2303 0 (offset 0)
# Ignoring wrong pointing object 2304 0 (offset 0)
# Ignoring wrong pointing object 2309 0 (offset 0)
# Ignoring wrong pointing object 2314 0 (offset 0)
# Ignoring wrong pointing object 2315 0 (offset 0)
# Ignoring wrong pointing object 2316 0 (offset 0)
# Ignoring wrong pointing object 2325 0 (offset 0)
# Ignoring wrong pointing object 2327 0 (offset 0)
# Ignoring wrong pointing object 2328 0 (offset 0)
# Ignoring wrong pointing object 2333 0 (offset 0)
# Ignoring wrong pointing object 2336 0 (offset 0)
# Ignoring wrong pointing object 2338 0 (offset 0)
# Ignoring wrong pointing object 2339 0 (offset 0)
# Ignoring wrong pointing object 2344 0 (offset 0)
# Ignoring wrong pointing object 2349 0 (offset 0)
# Ignoring wrong pointing object 2351 0 (offset 0)
# Ignoring wrong pointing object 2352 0 (offset 0)
# Ignoring wrong pointing object 2353 0 (offset 0)
# Ignoring wrong pointing object 2354 0 (offset 0)
# Ignoring wrong pointing object 2359 0 (offset 0)
# Ignoring wrong pointing object 2365 0 (offset 0)
# Ignoring wrong pointing object 2366 0 (offset 0)
# Ignoring wrong pointing object 2367 0 (offset 0)
# Ignoring wrong pointing object 2374 0 (offset 0)
# Ignoring wrong pointing object 2375 0 (offset 0)
# Ignoring wrong pointing object 2376 0 (offset 0)
# Ignoring wrong pointing object 2380 0 (offset 0)
# Ignoring wrong pointing object 2387 0 (offset 0)
# Ignoring wrong pointing object 2389 0 (offset 0)
# Ignoring wrong pointing object 2390 0 (offset 0)
# Ignoring wrong pointing object 2397 0 (offset 0)
# Ignoring wrong pointing object 2399 0 (offset 0)
# Ignoring wrong pointing object 2400 0 (offset 0)
# Ignoring wrong pointing object 2404 0 (offset 0)
# Ignoring wrong pointing object 2408 0 (offset 0)
# Ignoring wrong pointing object 2411 0 (offset 0)
# Ignoring wrong pointing object 2415 0 (offset 0)
# Ignoring wrong pointing object 2422 0 (offset 0)
# Ignoring wrong pointing object 2424 0 (offset 0)
# Ignoring wrong pointing object 2425 0 (offset 0)
# Ignoring wrong pointing object 2433 0 (offset 0)
# Ignoring wrong pointing object 2434 0 (offset 0)
# Ignoring wrong pointing object 2435 0 (offset 0)
# Ignoring wrong pointing object 2438 0 (offset 0)
# Ignoring wrong pointing object 2449 0 (offset 0)
# Ignoring wrong pointing object 2451 0 (offset 0)
# Ignoring wrong pointing object 2452 0 (offset 0)
# Ignoring wrong pointing object 2460 0 (offset 0)
# Ignoring wrong pointing object 2461 0 (offset 0)
# Ignoring wrong pointing object 2462 0 (offset 0)
# Ignoring wrong pointing object 2465 0 (offset 0)
# Ignoring wrong pointing object 2468 0 (offset 0)
# Ignoring wrong pointing object 2473 0 (offset 0)
# Ignoring wrong pointing object 2478 0 (offset 0)
# Ignoring wrong pointing object 2480 0 (offset 0)
# Ignoring wrong pointing object 2481 0 (offset 0)
# Ignoring wrong pointing object 2486 0 (offset 0)
# Ignoring wrong pointing object 2497 0 (offset 0)
# Ignoring wrong pointing object 2498 0 (offset 0)
# Ignoring wrong pointing object 2499 0 (offset 0)
# Ignoring wrong pointing object 2502 0 (offset 0)
# Ignoring wrong pointing object 2506 0 (offset 0)
# Ignoring wrong pointing object 2512 0 (offset 0)
# Ignoring wrong pointing object 2513 0 (offset 0)
# Ignoring wrong pointing object 2523 0 (offset 0)
# Ignoring wrong pointing object 2524 0 (offset 0)
# Ignoring wrong pointing object 2526 0 (offset 0)
# Ignoring wrong pointing object 2527 0 (offset 0)
# Ignoring wrong pointing object 2531 0 (offset 0)
# Ignoring wrong pointing object 2536 0 (offset 0)
# Ignoring wrong pointing object 2543 0 (offset 0)
# Ignoring wrong pointing object 2545 0 (offset 0)
# Ignoring wrong pointing object 2546 0 (offset 0)
# Ignoring wrong pointing object 2547 0 (offset 0)
# Ignoring wrong pointing object 2548 0 (offset 0)
# Ignoring wrong pointing object 2554 0 (offset 0)
# Ignoring wrong pointing object 2555 0 (offset 0)
# Ignoring wrong pointing object 2556 0 (offset 0)
# Ignoring wrong pointing object 2563 0 (offset 0)
# Ignoring wrong pointing object 2564 0 (offset 0)
# Ignoring wrong pointing object 2565 0 (offset 0)
# Ignoring wrong pointing object 2571 0 (offset 0)
# Ignoring wrong pointing object 2572 0 (offset 0)
# Ignoring wrong pointing object 2573 0 (offset 0)
# Ignoring wrong pointing object 2576 0 (offset 0)
# Ignoring wrong pointing object 2581 0 (offset 0)
# Ignoring wrong pointing object 2591 0 (offset 0)
# Ignoring wrong pointing object 2592 0 (offset 0)
# Ignoring wrong pointing object 2593 0 (offset 0)
# Ignoring wrong pointing object 2596 0 (offset 0)
# Ignoring wrong pointing object 2606 0 (offset 0)
# Ignoring wrong pointing object 2607 0 (offset 0)
# Ignoring wrong pointing object 2608 0 (offset 0)
# Ignoring wrong pointing object 2609 0 (offset 0)
# Ignoring wrong pointing object 2610 0 (offset 0)
# Ignoring wrong pointing object 2623 0 (offset 0)
# Ignoring wrong pointing object 2624 0 (offset 0)
# Ignoring wrong pointing object 2625 0 (offset 0)
# Ignoring wrong pointing object 2630 0 (offset 0)
# Ignoring wrong pointing object 2637 0 (offset 0)
# Ignoring wrong pointing object 2638 0 (offset 0)
# Ignoring wrong pointing object 2639 0 (offset 0)
# Ignoring wrong pointing object 2650 0 (offset 0)
# Ignoring wrong pointing object 2651 0 (offset 0)
# Ignoring wrong pointing object 2652 0 (offset 0)
# Ignoring wrong pointing object 2655 0 (offset 0)
# Ignoring wrong pointing object 2663 0 (offset 0)
# Ignoring wrong pointing object 2665 0 (offset 0)
# Ignoring wrong pointing object 2666 0 (offset 0)
# Ignoring wrong pointing object 2669 0 (offset 0)
# Ignoring wrong pointing object 2677 0 (offset 0)
# Ignoring wrong pointing object 2678 0 (offset 0)
# Ignoring wrong pointing object 2679 0 (offset 0)
# Ignoring wrong pointing object 2687 0 (offset 0)
# Ignoring wrong pointing object 2688 0 (offset 0)
# Ignoring wrong pointing object 2689 0 (offset 0)
# Ignoring wrong pointing object 2694 0 (offset 0)
# Ignoring wrong pointing object 2705 0 (offset 0)
# Ignoring wrong pointing object 2706 0 (offset 0)
# Ignoring wrong pointing object 2707 0 (offset 0)
# Ignoring wrong pointing object 2713 0 (offset 0)
# Ignoring wrong pointing object 2714 0 (offset 0)
# Ignoring wrong pointing object 2715 0 (offset 0)
# Ignoring wrong pointing object 2728 0 (offset 0)
# Ignoring wrong pointing object 2729 0 (offset 0)
# Ignoring wrong pointing object 2730 0 (offset 0)
# Ignoring wrong pointing object 2731 0 (offset 0)
# Ignoring wrong pointing object 2732 0 (offset 0)
# Ignoring wrong pointing object 2735 0 (offset 0)
# Ignoring wrong pointing object 2743 0 (offset 0)
# Ignoring wrong pointing object 2744 0 (offset 0)
# Ignoring wrong pointing object 2745 0 (offset 0)
# Ignoring wrong pointing object 2748 0 (offset 0)
# Ignoring wrong pointing object 2754 0 (offset 0)
# Ignoring wrong pointing object 2755 0 (offset 0)
# Ignoring wrong pointing object 2756 0 (offset 0)
# Ignoring wrong pointing object 2760 0 (offset 0)
# Ignoring wrong pointing object 2765 0 (offset 0)
# Ignoring wrong pointing object 2766 0 (offset 0)
# Ignoring wrong pointing object 2767 0 (offset 0)
# Ignoring wrong pointing object 2774 0 (offset 0)
# Ignoring wrong pointing object 2776 0 (offset 0)
# Ignoring wrong pointing object 2777 0 (offset 0)
# Ignoring wrong pointing object 2780 0 (offset 0)
# Ignoring wrong pointing object 2794 0 (offset 0)
# Ignoring wrong pointing object 2795 0 (offset 0)
# Ignoring wrong pointing object 2796 0 (offset 0)
# Ignoring wrong pointing object 2797 0 (offset 0)
# Ignoring wrong pointing object 2798 0 (offset 0)
# Ignoring wrong pointing object 2802 0 (offset 0)
# Ignoring wrong pointing object 2805 0 (offset 0)
# Ignoring wrong pointing object 2813 0 (offset 0)
# Ignoring wrong pointing object 2815 0 (offset 0)
# Ignoring wrong pointing object 2816 0 (offset 0)
# Ignoring wrong pointing object 2821 0 (offset 0)
# Ignoring wrong pointing object 2828 0 (offset 0)
# Ignoring wrong pointing object 2830 0 (offset 0)
# Ignoring wrong pointing object 2831 0 (offset 0)
# Ignoring wrong pointing object 2851 0 (offset 0)
# Ignoring wrong pointing object 2853 0 (offset 0)
# Ignoring wrong pointing object 2854 0 (offset 0)
# Ignoring wrong pointing object 2855 0 (offset 0)
# Ignoring wrong pointing object 2856 0 (offset 0)
# Ignoring wrong pointing object 2877 0 (offset 0)
# Ignoring wrong pointing object 2878 0 (offset 0)
# Ignoring wrong pointing object 2879 0 (offset 0)
# Ignoring wrong pointing object 2880 0 (offset 0)
# Ignoring wrong pointing object 2881 0 (offset 0)
# Ignoring wrong pointing object 2899 0 (offset 0)
# Ignoring wrong pointing object 2900 0 (offset 0)
# Ignoring wrong pointing object 2901 0 (offset 0)
# Ignoring wrong pointing object 2902 0 (offset 0)
# Ignoring wrong pointing object 2903 0 (offset 0)
# Ignoring wrong pointing object 2909 0 (offset 0)
# Ignoring wrong pointing object 2913 0 (offset 0)
# Ignoring wrong pointing object 2915 0 (offset 0)
# Ignoring wrong pointing object 2916 0 (offset 0)
# Ignoring wrong pointing object 2920 0 (offset 0)
# Ignoring wrong pointing object 2922 0 (offset 0)
# Ignoring wrong pointing object 2923 0 (offset 0)
# Ignoring wrong pointing object 2926 0 (offset 0)
# Ignoring wrong pointing object 2930 0 (offset 0)
# Ignoring wrong pointing object 2934 0 (offset 0)
# Ignoring wrong pointing object 2938 0 (offset 0)
# Ignoring wrong pointing object 2942 0 (offset 0)
# Ignoring wrong pointing object 2946 0 (offset 0)
# Ignoring wrong pointing object 2955 0 (offset 0)
# Ignoring wrong pointing object 2956 0 (offset 0)
# Ignoring wrong pointing object 2957 0 (offset 0)
# Ignoring wrong pointing object 4001 0 (offset 0)
# Ignoring wrong pointing object 4002 0 (offset 0)
# Ignoring wrong pointing object 4003 0 (offset 0)
# Ignoring wrong pointing object 4004 0 (offset 0)
# Ignoring wrong pointing object 4005 0 (offset 0)
# Ignoring wrong pointing object 4006 0 (offset 0)
# Ignoring wrong pointing object 4007 0 (offset 0)
# Ignoring wrong pointing object 4008 0 (offset 0)
# Ignoring wrong pointing object 4009 0 (offset 0)
# Ignoring wrong pointing object 4010 0 (offset 0)
# Ignoring wrong pointing object 4011 0 (offset 0)
# Ignoring wrong pointing object 4012 0 (offset 0)
# Ignoring wrong pointing object 4013 0 (offset 0)
# Ignoring wrong pointing object 4495 0 (offset 0)
# Ignoring wrong pointing object 4497 0 (offset 0)
# Ignoring wrong pointing object 4499 0 (offset 0)
# Ignoring wrong pointing object 4502 0 (offset 0)
# Ignoring wrong pointing object 4504 0 (offset 0)
# Ignoring wrong pointing object 4506 0 (offset 0)
# Ignoring wrong pointing object 4509 0 (offset 0)
# Ignoring wrong pointing object 4511 0 (offset 0)
# Ignoring wrong pointing object 4513 0 (offset 0)
# Ignoring wrong pointing object 4516 0 (offset 0)
# Ignoring wrong pointing object 4518 0 (offset 0)
# Ignoring wrong pointing object 4521 0 (offset 0)
# Ignoring wrong pointing object 4523 0 (offset 0)
# Ignoring wrong pointing object 4526 0 (offset 0)
# Ignoring wrong pointing object 4528 0 (offset 0)
# Ignoring wrong pointing object 4533 0 (offset 0)
# Ignoring wrong pointing object 4535 0 (offset 0)
# Ignoring wrong pointing object 4536 0 (offset 0)
# Ignoring wrong pointing object 4539 0 (offset 0)
# Ignoring wrong pointing object 4541 0 (offset 0)
# Ignoring wrong pointing object 4544 0 (offset 0)
# Ignoring wrong pointing object 4546 0 (offset 0)
# Ignoring wrong pointing object 4549 0 (offset 0)
# Ignoring wrong pointing object 4551 0 (offset 0)
# Ignoring wrong pointing object 4571 0 (offset 0)
# Ignoring wrong pointing object 4572 0 (offset 0)
# Ignoring wrong pointing object 4573 0 (offset 0)
# Ignoring wrong pointing object 4574 0 (offset 0)
# Ignoring wrong pointing object 4575 0 (offset 0)
# Ignoring wrong pointing object 4576 0 (offset 0)
# Ignoring wrong pointing object 4577 0 (offset 0)
# Ignoring wrong pointing object 4578 0 (offset 0)
# Ignoring wrong pointing object 4581 0 (offset 0)
# Ignoring wrong pointing object 4582 0 (offset 0)
# Ignoring wrong pointing object 4920 0 (offset 0)
# Ignoring wrong pointing object 4938 0 (offset 0)
# Ignoring wrong pointing object 4939 0 (offset 0)
# Ignoring wrong pointing object 4940 0 (offset 0)
# Ignoring wrong pointing object 4941 0 (offset 0)
# Ignoring wrong pointing object 4942 0 (offset 0)
# Ignoring wrong pointing object 4943 0 (offset 0)
# Ignoring wrong pointing object 4944 0 (offset 0)
# Ignoring wrong pointing object 4945 0 (offset 0)
# Ignoring wrong pointing object 4946 0 (offset 0)
# Ignoring wrong pointing object 4947 0 (offset 0)
# Ignoring wrong pointing object 4948 0 (offset 0)
# Ignoring wrong pointing object 4949 0 (offset 0)
# Ignoring wrong pointing object 4950 0 (offset 0)
# Ignoring wrong pointing object 4951 0 (offset 0)
# Ignoring wrong pointing object 4952 0 (offset 0)
# Ignoring wrong pointing object 4953 0 (offset 0)
# Ignoring wrong pointing object 4954 0 (offset 0)
# Ignoring wrong pointing object 4955 0 (offset 0)
# Ignoring wrong pointing object 4956 0 (offset 0)
# Ignoring wrong pointing object 4957 0 (offset 0)
# Ignoring wrong pointing object 4958 0 (offset 0)
# Ignoring wrong pointing object 4959 0 (offset 0)
# Ignoring wrong pointing object 4960 0 (offset 0)
# Ignoring wrong pointing object 4961 0 (offset 0)
# Ignoring wrong pointing object 4962 0 (offset 0)
# Ignoring wrong pointing object 4963 0 (offset 0)
# Ignoring wrong pointing object 4964 0 (offset 0)
# Ignoring wrong pointing object 4965 0 (offset 0)
# Ignoring wrong pointing object 4966 0 (offset 0)
# Ignoring wrong pointing object 4967 0 (offset 0)
# Ignoring wrong pointing object 4968 0 (offset 0)
# Ignoring wrong pointing object 4969 0 (offset 0)
# Ignoring wrong pointing object 4970 0 (offset 0)
# Ignoring wrong pointing object 4971 0 (offset 0)
# Ignoring wrong pointing object 4972 0 (offset 0)
# Ignoring wrong pointing object 4973 0 (offset 0)
# Ignoring wrong pointing object 4974 0 (offset 0)
# Ignoring wrong pointing object 4975 0 (offset 0)
# Ignoring wrong pointing object 4976 0 (offset 0)
# Ignoring wrong pointing object 4977 0 (offset 0)
# Ignoring wrong pointing object 4978 0 (offset 0)
# Ignoring wrong pointing object 4979 0 (offset 0)
# Ignoring wrong pointing object 4980 0 (offset 0)
# Ignoring wrong pointing object 4981 0 (offset 0)
# Ignoring wrong pointing object 4982 0 (offset 0)
# Ignoring wrong pointing object 4983 0 (offset 0)
# Ignoring wrong pointing object 4984 0 (offset 0)
# Ignoring wrong pointing object 4985 0 (offset 0)
# Ignoring wrong pointing object 4986 0 (offset 0)
# Ignoring wrong pointing object 4987 0 (offset 0)
# Ignoring wrong pointing object 4988 0 (offset 0)
# Ignoring wrong pointing object 4989 0 (offset 0)
# Ignoring wrong pointing object 4990 0 (offset 0)
# Ignoring wrong pointing object 4991 0 (offset 0)
# Ignoring wrong pointing object 4992 0 (offset 0)
# Ignoring wrong pointing object 4993 0 (offset 0)
# Ignoring wrong pointing object 4994 0 (offset 0)
# Ignoring wrong pointing object 4995 0 (offset 0)
# Ignoring wrong pointing object 4996 0 (offset 0)
# Ignoring wrong pointing object 4997 0 (offset 0)
# Ignoring wrong pointing object 4998 0 (offset 0)
# Ignoring wrong pointing object 4999 0 (offset 0)
# Ignoring wrong pointing object 5000 0 (offset 0)
# Ignoring wrong pointing object 5001 0 (offset 0)
# Ignoring wrong pointing object 5002 0 (offset 0)
# Ignoring wrong pointing object 5003 0 (offset 0)
# Ignoring wrong pointing object 5004 0 (offset 0)
# Ignoring wrong pointing object 5005 0 (offset 0)
# Ignoring wrong pointing object 5006 0 (offset 0)
# Ignoring wrong pointing object 5007 0 (offset 0)
# Ignoring wrong pointing object 5008 0 (offset 0)
# Ignoring wrong pointing object 5009 0 (offset 0)
# Ignoring wrong pointing object 5010 0 (offset 0)
# Ignoring wrong pointing object 5011 0 (offset 0)
# Ignoring wrong pointing object 5012 0 (offset 0)
# Ignoring wrong pointing object 5013 0 (offset 0)
# Ignoring wrong pointing object 5014 0 (offset 0)
# Ignoring wrong pointing object 5015 0 (offset 0)
# Ignoring wrong pointing object 5016 0 (offset 0)
# Ignoring wrong pointing object 5017 0 (offset 0)
# Ignoring wrong pointing object 5018 0 (offset 0)
# Ignoring wrong pointing object 5019 0 (offset 0)
# Ignoring wrong pointing object 5020 0 (offset 0)
# Ignoring wrong pointing object 5021 0 (offset 0)
# Ignoring wrong pointing object 5022 0 (offset 0)
# Ignoring wrong pointing object 5023 0 (offset 0)
# Ignoring wrong pointing object 5024 0 (offset 0)
# Ignoring wrong pointing object 5025 0 (offset 0)
# Ignoring wrong pointing object 5026 0 (offset 0)
# Ignoring wrong pointing object 5027 0 (offset 0)
# Ignoring wrong pointing object 5028 0 (offset 0)
# Ignoring wrong pointing object 5029 0 (offset 0)
# Ignoring wrong pointing object 5030 0 (offset 0)
# Ignoring wrong pointing object 5031 0 (offset 0)
# Ignoring wrong pointing object 5032 0 (offset 0)
# Ignoring wrong pointing object 5033 0 (offset 0)
# Ignoring wrong pointing object 5034 0 (offset 0)
# Ignoring wrong pointing object 5035 0 (offset 0)
# Ignoring wrong pointing object 5036 0 (offset 0)
# Ignoring wrong pointing object 5037 0 (offset 0)
# Ignoring wrong pointing object 5038 0 (offset 0)
# Ignoring wrong pointing object 5039 0 (offset 0)
# Ignoring wrong pointing object 5040 0 (offset 0)
# Ignoring wrong pointing object 5041 0 (offset 0)
# Ignoring wrong pointing object 5042 0 (offset 0)
# Ignoring wrong pointing object 5043 0 (offset 0)
# Ignoring wrong pointing object 5044 0 (offset 0)
# Ignoring wrong pointing object 5045 0 (offset 0)
# Ignoring wrong pointing object 5046 0 (offset 0)
# Ignoring wrong pointing object 5047 0 (offset 0)
# Ignoring wrong pointing object 5048 0 (offset 0)
# Ignoring wrong pointing object 5049 0 (offset 0)
# Ignoring wrong pointing object 5050 0 (offset 0)
# Ignoring wrong pointing object 5051 0 (offset 0)
# Ignoring wrong pointing object 5052 0 (offset 0)
# Ignoring wrong pointing object 5053 0 (offset 0)
# Ignoring wrong pointing object 5054 0 (offset 0)
# Ignoring wrong pointing object 5055 0 (offset 0)
# Ignoring wrong pointing object 5056 0 (offset 0)
# Ignoring wrong pointing object 5057 0 (offset 0)
# Ignoring wrong pointing object 5058 0 (offset 0)
# Ignoring wrong pointing object 5059 0 (offset 0)
# Ignoring wrong pointing object 5060 0 (offset 0)
# Ignoring wrong pointing object 5061 0 (offset 0)
# Ignoring wrong pointing object 5062 0 (offset 0)
# Ignoring wrong pointing object 5063 0 (offset 0)
# Ignoring wrong pointing object 5064 0 (offset 0)
# Ignoring wrong pointing object 5065 0 (offset 0)
# Ignoring wrong pointing object 5066 0 (offset 0)
# Ignoring wrong pointing object 5067 0 (offset 0)
# Ignoring wrong pointing object 5068 0 (offset 0)
# Ignoring wrong pointing object 5069 0 (offset 0)
# Ignoring wrong pointing object 5070 0 (offset 0)
# Ignoring wrong pointing object 5071 0 (offset 0)
# Ignoring wrong pointing object 5072 0 (offset 0)
# Ignoring wrong pointing object 5073 0 (offset 0)
# Ignoring wrong pointing object 5074 0 (offset 0)
# Ignoring wrong pointing object 5075 0 (offset 0)
# Ignoring wrong pointing object 5076 0 (offset 0)
# Ignoring wrong pointing object 5077 0 (offset 0)
# Ignoring wrong pointing object 5078 0 (offset 0)
# Ignoring wrong pointing object 5079 0 (offset 0)
# Ignoring wrong pointing object 5080 0 (offset 0)
# Ignoring wrong pointing object 5081 0 (offset 0)
# Ignoring wrong pointing object 5082 0 (offset 0)
# Ignoring wrong pointing object 5083 0 (offset 0)
# Ignoring wrong pointing object 5084 0 (offset 0)
# Ignoring wrong pointing object 5085 0 (offset 0)
# Ignoring wrong pointing object 5086 0 (offset 0)
# Ignoring wrong pointing object 5087 0 (offset 0)
# Ignoring wrong pointing object 5088 0 (offset 0)
# Ignoring wrong pointing object 5089 0 (offset 0)
# Ignoring wrong pointing object 5090 0 (offset 0)
# Ignoring wrong pointing object 5091 0 (offset 0)
# Ignoring wrong pointing object 5092 0 (offset 0)
# Ignoring wrong pointing object 5093 0 (offset 0)
# Ignoring wrong pointing object 5094 0 (offset 0)
# Ignoring wrong pointing object 5095 0 (offset 0)
# Ignoring wrong pointing object 5096 0 (offset 0)
# Ignoring wrong pointing object 5097 0 (offset 0)
# Ignoring wrong pointing object 5098 0 (offset 0)
# Ignoring wrong pointing object 5099 0 (offset 0)
# Ignoring wrong pointing object 5100 0 (offset 0)
# Ignoring wrong pointing object 5101 0 (offset 0)
# Ignoring wrong pointing object 5102 0 (offset 0)
# Ignoring wrong pointing object 5103 0 (offset 0)
# Ignoring wrong pointing object 5104 0 (offset 0)
# Ignoring wrong pointing object 5105 0 (offset 0)
# Ignoring wrong pointing object 5106 0 (offset 0)
# Ignoring wrong pointing object 5107 0 (offset 0)
# Ignoring wrong pointing object 5108 0 (offset 0)
# Ignoring wrong pointing object 5109 0 (offset 0)
# Ignoring wrong pointing object 5110 0 (offset 0)
# Ignoring wrong pointing object 5111 0 (offset 0)
# Ignoring wrong pointing object 5112 0 (offset 0)
# Ignoring wrong pointing object 5113 0 (offset 0)
# Ignoring wrong pointing object 5114 0 (offset 0)
# Ignoring wrong pointing object 5115 0 (offset 0)
# Ignoring wrong pointing object 5116 0 (offset 0)
# Ignoring wrong pointing object 5117 0 (offset 0)
# Ignoring wrong pointing object 5118 0 (offset 0)
# Ignoring wrong pointing object 5119 0 (offset 0)
# Ignoring wrong pointing object 5120 0 (offset 0)
# Ignoring wrong pointing object 5121 0 (offset 0)
# Ignoring wrong pointing object 5122 0 (offset 0)
# Ignoring wrong pointing object 5123 0 (offset 0)
# Ignoring wrong pointing object 5124 0 (offset 0)
# Ignoring wrong pointing object 5125 0 (offset 0)
# Ignoring wrong pointing object 5126 0 (offset 0)
# Ignoring wrong pointing object 5127 0 (offset 0)
# Ignoring wrong pointing object 5128 0 (offset 0)
# Ignoring wrong pointing object 5129 0 (offset 0)
# Ignoring wrong pointing object 5130 0 (offset 0)
# Ignoring wrong pointing object 5131 0 (offset 0)
# Ignoring wrong pointing object 5132 0 (offset 0)
# Ignoring wrong pointing object 5133 0 (offset 0)
# Ignoring wrong pointing object 5134 0 (offset 0)
# Ignoring wrong pointing object 5135 0 (offset 0)
# Ignoring wrong pointing object 5136 0 (offset 0)
# Ignoring wrong pointing object 5137 0 (offset 0)
# Ignoring wrong pointing object 5138 0 (offset 0)
# Ignoring wrong pointing object 5139 0 (offset 0)
# Ignoring wrong pointing object 5140 0 (offset 0)
# Ignoring wrong pointing object 5141 0 (offset 0)
# Ignoring wrong pointing object 5142 0 (offset 0)
# Ignoring wrong pointing object 5143 0 (offset 0)
# Ignoring wrong pointing object 5144 0 (offset 0)
# Ignoring wrong pointing object 5145 0 (offset 0)
# Ignoring wrong pointing object 5146 0 (offset 0)
# Ignoring wrong pointing object 5147 0 (offset 0)
# Ignoring wrong pointing object 5148 0 (offset 0)
# Ignoring wrong pointing object 5149 0 (offset 0)
# Ignoring wrong pointing object 5150 0 (offset 0)
# Ignoring wrong pointing object 5151 0 (offset 0)
# Ignoring wrong pointing object 5152 0 (offset 0)
# Ignoring wrong pointing object 5153 0 (offset 0)
# Ignoring wrong pointing object 5154 0 (offset 0)
# Ignoring wrong pointing object 5155 0 (offset 0)
# Ignoring wrong pointing object 5156 0 (offset 0)
# Ignoring wrong pointing object 5157 0 (offset 0)
# Ignoring wrong pointing object 5158 0 (offset 0)
# Ignoring wrong pointing object 5159 0 (offset 0)
# Ignoring wrong pointing object 5160 0 (offset 0)
# Ignoring wrong pointing object 5161 0 (offset 0)
# Ignoring wrong pointing object 5162 0 (offset 0)
# Ignoring wrong pointing object 5163 0 (offset 0)
# Ignoring wrong pointing object 5164 0 (offset 0)
# Ignoring wrong pointing object 5165 0 (offset 0)
# Ignoring wrong pointing object 5166 0 (offset 0)
# Ignoring wrong pointing object 5167 0 (offset 0)
# Ignoring wrong pointing object 5168 0 (offset 0)
# Ignoring wrong pointing object 5169 0 (offset 0)
# Ignoring wrong pointing object 5170 0 (offset 0)
# Ignoring wrong pointing object 5172 0 (offset 0)
# Ignoring wrong pointing object 5174 0 (offset 0)
# Ignoring wrong pointing object 5175 0 (offset 0)
# Ignoring wrong pointing object 5176 0 (offset 0)

# %%
from langchain_groq import ChatGroq
from env import groq_api_key
llm = ChatGroq(
            groq_api_key=groq_api_key,
            model_name='mixtral-8x7b-32768'
    )


#https://github.com/ollama/ollama

# from langchain_community.llms import Ollama

# llm = Ollama(model="llama2")

# llm.invoke("Tell me a joke")

# %%
rag_template = """Answer the question based only on the following context:
{context}
Question: {question}
"""
rag_prompt = ChatPromptTemplate.from_template(rag_template)
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | rag_prompt
    | llm
    | StrOutputParser()
)

# %%
import os
import time
import textwrap
import gradio as gr

# Test the architecture with a simple hard coded question
response = rag_chain.invoke("What is this document about")
print(textwrap.fill(response, width=80))
# Out:
# The document discusses the MapReduce programming model and its use in processing
# large datasets. It explains how MapReduce can be used to process data in
# parallel across multiple machines, by having each machine run the mapper
# function on its local data, distributing the resulting (key, value) pairs to
# reducing machines for further processing, and then returning the final (key,
# output) pairs. The model allows for processing large datasets that are
# distributed across multiple machines, without requiring all data to be
# transferred to a single machine. The document is a part of the "Data Science
# from Scratch" book.

# %%
# Make the questions dynamic using a chat interface. Let's use gradio for this.
def process_question(user_question):
    start_time = time.time()

    # Directly using the user's question as input for rag_chain.invoke
    response = rag_chain.invoke(user_question)

    # Measure the response time
    end_time = time.time()
    response_time = f"Response time: {end_time - start_time:.2f} seconds."

    # Combine the response and the response time into a single string
    full_response = f"{response}\n\n{response_time}"

    return full_response

# Setup the Gradio interface
iface = gr.Interface(fn=process_question,
                     inputs=gr.Textbox(lines=2, placeholder="Type your question here..."),
                     outputs=gr.Textbox(),
                     title="Personal Knowledge Chat App",
                     description="Ask any question about your document, and get an answer along with the response time.")

# Launch the interface
iface.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://218aad936f9561256b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://218aad936f9561256b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
